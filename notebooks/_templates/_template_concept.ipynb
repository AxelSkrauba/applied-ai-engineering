# %% [markdown]
# # Título del Concepto/Técnica
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AxelSkrauba/applied-ai-engineering/blob/main/notebooks/ruta/al/notebook.ipynb)

# %% [markdown]
# ## Objetivos

# %% [markdown]
# Breve descripción de los objetivos (1-3 puntos).
# - Comprender el concepto X.
# - Implementar Y usando la librería Z.

# %% [markdown]
# ## Prerrequisitos

# %% [markdown]
# Conceptos o notebooks previos recomendados.
# - Conocimientos básicos de [Tema previo].
# - Haber completado: [Notebook anterior](../capitulo/notebook_anterior.ipynb).
#
# ---

# %% [markdown]
# ## Configuración del Entorno

# %%
# @title *Esta celda clona el repositorio (en Colab) e importa las utilidades comunes*
import sys
import os

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    import subprocess
    REPO_NAME = "applied-ai-engineering"
    if not os.path.exists(REPO_NAME):
        subprocess.run(["git", "clone", "https://github.com/AxelSkrauba/applied-ai-engineering.git"], check=True)
    os.chdir(f"/content/{REPO_NAME}")
    sys.path.append(f"/content/{REPO_NAME}")
else:
    # Repositorio en local, apuntar path a la raiz
    os.chdir(f"../../")

from utils.plots import setup_plot_style
setup_plot_style()

# %% [markdown]
# ## Introducción Teórica

# %% [markdown]
# Explicación del concepto. Usa matemáticas (LaTeX) si es necesario:
# $$ y = mx + b $$
#
# Narrativa enfocada en el "por qué" y "cómo funciona" a nivel intuitivo.

# %% [markdown]
# ## Desarrollo e Implementación

# %% [markdown]
# Código explicativo, con celdas de código y texto intercaladas.

# %%
# El código aquí
import numpy as np
import matplotlib.pyplot as plt

# plt.plot([1, 2, 3], [1, 4, 9])
# plt.title("Ejemplo de Gráfico con Estilo Estandarizado")
# plt.show()

# %% [markdown]
# ## Resultados y Discusión

# %% [markdown]
# Análisis de los resultados obtenidos en las celdas anteriores. ¿Qué nos dicen estos datos/gráficos?

# %% [markdown]
# ## Conexiones y Próximos Pasos

# %% [markdown]
# - ➡️ **Siguiente:** [Notebook siguiente](../capitulo/notebook_siguiente.ipynb)
# - 🔄 **Relacionado:** [Otro concepto similar](../capitulo/relacionado.ipynb)

# %% [markdown]
# ## Referencias

# %% [markdown]
# 1. [Autor, Año]. Título del paper o libro. Editorial o Enlace.
# 2. [Documentación de Librería](https://...)
#
# ---

# %% [markdown]
# ## Entorno de Ejecución

# %% [markdown]
# Registro de versiones para asegurar reproducibilidad.

# %%
from utils.environment import environment_table
environment_table(include_all=False)
